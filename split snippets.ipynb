# %%
# -*- coding: utf-8 -*-
"""ResearchPaperReadAndSplit.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1WIwbZ7WACOGiXF4WI5SpYWzRA5Thn25q
"""

###pip install tika
from tika import parser
import glob
import re

# %%
dir = 'C:/Users/Evan/Documents/7180QueryTool/Data/*'
for research_paper_name in glob.glob(dir):
  print(research_paper_name)
  research_paper_data = parser.from_file(research_paper_name)
  research_paper_content = research_paper_data['content']
  paragraphs = research_paper_content.split("\n\n")
  print(paragraphs)

  research_paper_txt_name = research_paper_name.replace("pdf","txt")
  rp_file= open(research_paper_txt_name,"w+")
  edited_paragraphs = []
  for i in range(len(paragraphs)):
    rp_file.write(str(paragraphs[i]))
    if paragraphs[i] != '':
      edited_paragraphs.append(paragraphs[i])
    if len(edited_paragraphs) != 0:
      edited_paragraphs[len(edited_paragraphs)-1] = re.sub(r"\n", "", edited_paragraphs[len(edited_paragraphs)-1] )
  print(edited_paragraphs)
  
  rp_file.close()
# Out:
# C:/Users/Evan/Documents/7180QueryTool/Data\C-SWM.pdf
# 2020-02-03 16:49:27,142 [MainThread  ] [ERROR]  Unable to run java; is it installed?
# 2020-02-03 16:49:27,143 [MainThread  ] [ERROR]  Failed to receive startup confirmation from startServer.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-cdd93fd7fb7f> in <module>()
#       2 for research_paper_name in glob.glob(dir):
#       3   print(research_paper_name)
# ----> 4   research_paper_data = parser.from_file(research_paper_name)
#       5   research_paper_content = research_paper_data['content']
#       6   paragraphs = research_paper_content.split("\n\n")
#
# ~\Anaconda3\lib\site-packages\tika\parser.py in from_file(filename, serverEndpoint, service, xmlContent, headers, config_path, requestOptions)
#      38     '''
#      39     if not xmlContent:
# ---> 40         output = parse1(service, filename, serverEndpoint, headers=headers, config_path=config_path, requestOptions=requestOptions)
#      41     else:
#      42         output = parse1(service, filename, serverEndpoint, services={'meta': '/meta', 'text': '/tika', 'all': '/rmeta/xml'},
#
# ~\Anaconda3\lib\site-packages\tika\tika.py in parse1(option, urlOrPath, serverEndpoint, verbose, tikaServerJar, responseMimeType, services, rawResponse, headers, config_path, requestOptions)
#     335         status, response = callServer('put', serverEndpoint, service, f,
#     336                                       headers, verbose, tikaServerJar, config_path=config_path,
# --> 337                                       rawResponse=rawResponse, requestOptions=requestOptions)
#     338
#     339     if file_type == 'remote': os.unlink(path)
#
# ~\Anaconda3\lib\site-packages\tika\tika.py in callServer(verb, serverEndpoint, service, data, headers, verbose, tikaServerJar, httpVerbs, classpath, rawResponse, config_path, requestOptions)
#     528     global TikaClientOnly
#     529     if not TikaClientOnly:
# --> 530         serverEndpoint = checkTikaServer(scheme, serverHost, port, tikaServerJar, classpath, config_path)
#     531
#     532     serviceUrl  = serverEndpoint + service
#
# ~\Anaconda3\lib\site-packages\tika\tika.py in checkTikaServer(scheme, serverHost, port, tikaServerJar, classpath, config_path)
#     598             if not status:
#     599                 log.error("Failed to receive startup confirmation from startServer.")
# --> 600                 raise RuntimeError("Unable to start Tika server.")
#     601     return serverEndpoint
#     602
#
# RuntimeError: Unable to start Tika server.
